# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.362412
# Nearest to often: birch, odyssey, impure, continuum, easternmost, dreaming, ven, dukedom,
# Nearest to years: artaxerxes, kongo, corsican, thorough, unstoppable, spoilage, superoxide, buccaneers,
# Nearest to all: sacrifice, handfasting, lectured, cenotaph, lasers, cabal, undisputed, gynecology,
# Nearest to UNK: ionia, calvin, lesund, hieroglyphic, pham, spokesperson, redmond, septic,
# Nearest to eight: immortal, prot, concocted, buckets, vizier, mbit, overflowing, gall,
# Nearest to between: paracetamol, cheddar, winner, specter, carvings, legal, instantaneously, microprogram,
# Nearest to these: inactivity, perennials, protege, eritrea, caters, compatriots, tata, restoration,
# Nearest to was: attacked, nate, rubber, carmelites, pcd, republik, beginning, injunction,
# Nearest to also: blockaded, stonehenge, baking, genealogies, bridgeport, hotham, principality, cunningham,
# Nearest to had: crts, hardback, fraenkel, tris, nutation, berners, kilimanjaro, rarity,
# Nearest to called: throttle, biola, semimajor, trivium, theologies, letterboxing, tris, keats,
# Nearest to to: cuailnge, decomposers, smuts, sights, feldman, micah, braun, ifbb,
# Nearest to known: sabotage, pegged, ching, laymen, partying, procellariiformes, syntax, klaus,
# Nearest to which: radiology, dog, mothman, jocular, racetrack, joints, youths, nanotubes,
# Nearest to and: christmas, secant, randy, treasured, slightest, fondation, tata, abundance,
# Nearest to one: germinal, sensitivities, discontinuous, flipper, hyperion, tub, madras, correlation,
# Average loss at step 2000: 4.365913
# Average loss at step 4000: 3.863856
# Average loss at step 6000: 3.795455
# Average loss at step 8000: 3.693689
# Average loss at step 10000: 3.618880
# Nearest to often: impure, also, disguises, continuum, birch, sometimes, odyssey, ven,
# Nearest to years: kongo, corsican, retiring, artaxerxes, firefly, cleaners, recounted, enchantment,
# Nearest to all: sacrifice, these, numerous, lectured, gynecology, around, cis, cenotaph,
# Nearest to UNK: flagella, anticipate, by, venlo, mand, bayard, gerd, basingstoke,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to between: from, legal, specter, with, handy, reston, cheddar, of,
# Nearest to these: inflationary, all, caters, social, symphonies, chang, asuras, acorns,
# Nearest to was: is, were, has, had, by, be, s, trusting,
# Nearest to also: never, neutral, blockaded, often, it, stonehenge, parmenides, overruns,
# Nearest to had: has, have, was, qantas, vibrate, nutation, been, domingue,
# Nearest to called: biola, semimajor, throttle, theologies, detainee, blondie, considered, daime,
# Nearest to to: not, would, micah, restructure, can, khartoum, yi, must,
# Nearest to known: such, sabotage, latinos, ching, dez, partying, used, livestock,
# Nearest to which: that, who, traded, it, racetrack, triumph, lbs, this,
# Nearest to and: or, who, s, d, birkhoff, resistivity, of, for,
# Nearest to one: two, three, six, seven, eight, four, five, killing,
# Average loss at step 12000: 3.604928
# Average loss at step 14000: 3.570858
# Average loss at step 16000: 3.414388
# Average loss at step 18000: 3.460569
# Average loss at step 20000: 3.536837
# Nearest to often: sometimes, generally, also, impure, disguises, which, commonly, birch,
# Nearest to years: corsican, kongo, firefly, remixed, stockpile, enchantment, pouch, implicate,
# Nearest to all: these, many, numerous, gynecology, some, several, ram, sacrifice,
# Nearest to UNK: conversant, viet, alias, kuan, center, corona, indulging, smells,
# Nearest to eight: seven, nine, six, five, four, three, two, zero,
# Nearest to between: from, with, through, reston, handy, legal, andhra, denise,
# Nearest to these: some, many, all, which, several, such, caters, acorns,
# Nearest to was: is, has, were, had, be, became, stiff, switch,
# Nearest to also: which, actually, usually, often, never, not, neutral, sometimes,
# Nearest to had: has, have, was, were, qantas, vibrate, been, radiometric,
# Nearest to called: biola, margins, appointing, throttle, semimajor, considered, uniting, brigid,
# Nearest to to: not, would, micah, decomposers, yi, cannot, for, from,
# Nearest to known: such, used, possible, dez, anaxagoras, livestock, sabotage, themselves,
# Nearest to which: that, who, this, but, also, it, these, there,
# Nearest to and: or, contraction, in, from, but, with, which, including,
# Nearest to one: two, four, three, six, seven, five, eight, nine,
# Average loss at step 22000: 3.504688
# Average loss at step 24000: 3.491778
# Average loss at step 26000: 3.487440
# Average loss at step 28000: 3.477450
# Average loss at step 30000: 3.507202
# Nearest to often: sometimes, usually, generally, commonly, also, impure, there, realaudio,
# Nearest to years: kongo, corsican, firefly, days, remixed, dignified, months, spoilage,
# Nearest to all: these, some, any, numerous, many, several, sacrifice, suggests,
# Nearest to UNK: flagella, dd, pergamum, anticipate, drives, whereupon, paulist, maliki,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to between: with, from, through, reston, into, handy, specter, andhra,
# Nearest to these: some, many, all, such, several, their, those, are,
# Nearest to was: is, had, has, were, became, being, when, been,
# Nearest to also: usually, never, actually, now, which, often, still, who,
# Nearest to had: has, have, was, were, qantas, is, would, vibrate,
# Nearest to called: considered, brigid, throttle, margins, antares, factually, protestantism, appointing,
# Nearest to to: would, must, can, will, micah, kore, cannot, menacing,
# Nearest to known: used, such, defined, possible, dez, well, anaxagoras, accepted,
# Nearest to which: this, that, who, there, also, it, but, however,
# Nearest to and: or, but, in, of, barge, who, morphologically, from,
# Nearest to one: two, four, seven, six, eight, three, five, nine,
# Average loss at step 32000: 3.505522
# Average loss at step 34000: 3.496318
# Average loss at step 36000: 3.454384
# Average loss at step 38000: 3.308739
# Average loss at step 40000: 3.430405
# Nearest to often: usually, sometimes, generally, commonly, also, widely, who, there,
# Nearest to years: days, decades, months, firefly, kongo, remixed, centuries, dignified,
# Nearest to all: sacrifice, these, any, pavlov, trasimene, absurdity, victors, members,
# Nearest to UNK: jackson, b, backstory, png, outcome, texan, shawar, frick,
# Nearest to eight: nine, seven, six, five, four, three, two, one,
# Nearest to between: with, through, from, reston, andhra, into, intv, carvings,
# Nearest to these: some, many, several, such, those, they, both, all,
# Nearest to was: is, has, were, had, became, be, being, been,
# Nearest to also: usually, which, often, now, still, actually, never, sometimes,
# Nearest to had: has, have, was, were, vibrate, been, kernels, qantas,
# Nearest to called: considered, volhynia, antares, where, ample, inventions, prentice, protestantism,
# Nearest to to: will, must, intensified, cannot, menacing, would, can, could,
# Nearest to known: used, defined, such, possible, dez, livestock, served, desai,
# Nearest to which: that, this, also, who, there, it, usually, often,
# Nearest to and: or, but, juanita, like, s, while, including, glaze,
# Nearest to one: seven, six, eight, four, two, five, nine, three,
# Average loss at step 42000: 3.437307
# Average loss at step 44000: 3.453273
# Average loss at step 46000: 3.448700
# Average loss at step 48000: 3.352482
# Average loss at step 50000: 3.389857
# Nearest to often: usually, generally, sometimes, commonly, also, widely, typically, now,
# Nearest to years: days, decades, months, centuries, year, firefly, kongo, remixed,
# Nearest to all: both, any, these, governorship, various, some, sacrifice, those,
# Nearest to UNK: de, phenyl, mujahedeen, backstory, tah, vandals, breaching, gaels,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to between: with, through, from, reston, in, intv, into, among,
# Nearest to these: some, many, such, both, several, those, squid, which,
# Nearest to was: is, were, has, had, became, be, been, being,
# Nearest to also: which, often, now, never, actually, usually, still, sometimes,
# Nearest to had: has, have, was, were, having, vibrate, been, won,
# Nearest to called: antares, ample, volhynia, typeset, known, inventions, brigid, sef,
# Nearest to to: kadyrov, must, could, menacing, will, intensified, cannot, would,
# Nearest to known: used, defined, possible, such, regarded, served, desai, available,
# Nearest to which: this, that, also, who, usually, but, what, often,
# Nearest to and: but, or, while, including, mot, of, in, organizes,
# Nearest to one: two, six, eight, seven, three, four, five, nine,
# Average loss at step 52000: 3.437972
# Average loss at step 54000: 3.428021
# Average loss at step 56000: 3.439328
# Average loss at step 58000: 3.395233
# Average loss at step 60000: 3.394529
# Nearest to often: sometimes, usually, generally, commonly, now, typically, widely, also,
# Nearest to years: days, decades, months, centuries, firefly, year, times, kongo,
# Nearest to all: both, those, any, these, many, some, various, every,
# Nearest to UNK: educators, tt, altaic, sufficiently, dipped, acupuncture, cowan, lesund,
# Nearest to eight: nine, six, four, seven, three, five, zero, one,
# Nearest to between: with, intv, through, among, guglielmo, in, reston, over,
# Nearest to these: some, many, several, those, such, both, squid, all,
# Nearest to was: is, became, had, has, were, be, been, nasrallah,
# Nearest to also: now, often, still, never, which, usually, actually, sometimes,
# Nearest to had: has, have, was, were, been, having, vibrate, could,
# Nearest to called: used, considered, known, typeset, brigid, protestantism, gasses, digraphs,
# Nearest to to: menacing, will, must, cuailnge, would, kadyrov, trombone, jacobian,
# Nearest to known: used, defined, possible, regarded, such, desai, talkative, available,
# Nearest to which: that, this, what, also, it, however, who, these,
# Nearest to and: or, but, than, juanita, including, although, however, antiquarian,
# Nearest to one: two, seven, six, four, eight, three, five, nine,
# Average loss at step 62000: 3.246758
# Average loss at step 64000: 3.260045
# Average loss at step 66000: 3.403809
# Average loss at step 68000: 3.395935
# Average loss at step 70000: 3.365348
# Nearest to often: sometimes, usually, commonly, generally, now, widely, typically, frequently,
# Nearest to years: days, decades, months, centuries, year, spoilage, brit, dignified,
# Nearest to all: many, any, various, some, both, those, dresses, every,
# Nearest to UNK: der, webring, whereupon, goss, html, plunge, shoguns, ria,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to between: with, from, among, within, intv, through, in, into,
# Nearest to these: some, many, such, several, are, those, which, ld,
# Nearest to was: is, has, had, were, became, be, been, when,
# Nearest to also: now, which, still, often, never, sometimes, usually, actually,
# Nearest to had: has, have, was, were, having, been, vibrate, could,
# Nearest to called: referred, considered, used, typeset, gasses, brigid, antares, known,
# Nearest to to: must, will, can, would, cuailnge, nihilism, tano, may,
# Nearest to known: used, defined, possible, regarded, such, desai, served, recognized,
# Nearest to which: that, this, also, but, usually, these, however, who,
# Nearest to and: or, juanita, while, but, which, rai, however, australopithecines,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Average loss at step 72000: 3.370480
# Average loss at step 74000: 3.348640
# Average loss at step 76000: 3.312055
# Average loss at step 78000: 3.351000
# Average loss at step 80000: 3.376845
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, now, widely,
# Nearest to years: days, decades, months, centuries, year, minutes, times, firefly,
# Nearest to all: both, every, many, any, various, dresses, sacrifice, unsolved,
# Nearest to UNK: earthbound, rwandan, johnson, singer, smith, e, anderson, ed,
# Nearest to eight: nine, six, five, four, seven, three, zero, two,
# Nearest to between: with, within, among, in, through, reston, guglielmo, intv,
# Nearest to these: those, several, many, such, some, they, both, ld,
# Nearest to was: is, were, became, had, has, being, been, when,
# Nearest to also: now, which, sometimes, often, still, actually, never, usually,
# Nearest to had: has, have, was, having, were, been, highbury, won,
# Nearest to called: considered, referred, known, used, pixels, brigid, typeset, fonda,
# Nearest to to: must, menacing, would, cuailnge, narrowly, proliferate, could, kenyan,
# Nearest to known: used, defined, regarded, possible, such, recognized, served, called,
# Nearest to which: that, this, also, what, usually, who, actually, but,
# Nearest to and: or, but, including, while, ian, organizes, laurens, juanita,
# Nearest to one: six, seven, two, three, four, five, eight, nine,
# Average loss at step 82000: 3.408245
# Average loss at step 84000: 3.410796
# Average loss at step 86000: 3.393415
# Average loss at step 88000: 3.355362
# Average loss at step 90000: 3.365557
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, widely,
# Nearest to years: days, decades, months, centuries, year, minutes, hours, times,
# Nearest to all: both, every, many, various, any, several, these, those,
# Nearest to UNK: lesund, thomas, eds, l, adverse, situational, jarrett, creations,
# Nearest to eight: five, seven, six, nine, four, three, zero, two,
# Nearest to between: with, within, among, from, in, intv, disregards, reston,
# Nearest to these: several, some, many, those, such, various, are, were,
# Nearest to was: is, had, became, were, has, been, be, omim,
# Nearest to also: now, still, which, actually, often, sometimes, never, usually,
# Nearest to had: has, have, was, having, were, vibrate, yet, been,
# Nearest to called: referred, considered, used, known, named, antares, aggregation, cimmerian,
# Nearest to to: towards, would, must, will, menacing, kadyrov, trombone, narrowly,
# Nearest to known: used, defined, such, regarded, served, possible, recognized, called,
# Nearest to which: that, also, this, who, usually, what, but, actually,
# Nearest to and: or, but, including, while, however, though, in, ursus,
# Nearest to one: seven, two, eight, four, six, three, five, nine,
# Average loss at step 92000: 3.398031
# Average loss at step 94000: 3.252929
# Average loss at step 96000: 3.355960
# Average loss at step 98000: 3.245381
# Average loss at step 100000: 3.360000
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, widely,
# Nearest to years: days, decades, months, year, centuries, minutes, hours, times,
# Nearest to all: various, every, both, those, these, many, some, several,
# Nearest to UNK: doesburg, lesund, whereupon, tights, incorporating, diena, clades, mand,
# Nearest to eight: seven, nine, six, four, five, three, two, zero,
# Nearest to between: with, among, intv, through, from, disregards, reston, guglielmo,
# Nearest to these: some, several, those, many, various, all, numerous, were,
# Nearest to was: is, had, became, has, were, been, being, although,
# Nearest to also: actually, now, never, sometimes, still, often, which, usually,
# Nearest to had: has, have, was, were, having, unisex, would, been,
# Nearest to called: referred, named, considered, used, known, attracted, buffers, mckernan,
# Nearest to to: will, must, could, would, should, towards, can, proliferate,
# Nearest to known: used, defined, such, possible, regarded, recognized, served, available,
# Nearest to which: that, this, usually, but, what, who, also, actually,
# Nearest to and: or, but, like, including, while, however, fuchs, although,
# Nearest to one: two, four, seven, six, eight, five, nine, three,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ skip_window target skip_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 4 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.599087
# Nearest to was: definition, contains, fatalities, satirists, clayton, neri, fincher, contested,
# Nearest to UNK: mayfair, nostalgic, identifying, inductance, overall, pacifists, belongings, declined,
# Nearest to they: scooby, fi, impaled, watery, alkane, recreated, organization, metropolitan,
# Nearest to but: elliott, gadolinium, proclamations, indiscriminate, valentin, humayun, julio, inhuman,
# Nearest to united: lamar, servile, temperate, amazingly, conics, goodman, snow, written,
# Nearest to years: protectionism, artefacts, safeguarding, mental, sutra, subfield, perception, ensure,
# Nearest to which: reefs, lighten, suzanne, cheyenne, culminate, lease, interventions, stratigraphic,
# Nearest to one: bce, alf, celebrate, paragon, io, staffing, karp, cessna,
# Nearest to between: hostilities, rising, blockade, emile, bac, worked, exhumed, essayist,
# Nearest to over: profoundly, ssbauer, lenin, unthinkable, communications, juries, courthouse, icann,
# Nearest to has: iii, morals, such, evo, dryden, unmodified, riverfront, libration,
# Nearest to who: burghers, prefaces, indirectly, engler, additive, heels, garbage, staccato,
# Nearest to after: colleen, chambre, lucrezia, slugging, kinderhook, disaccharides, expired, afoul,
# Nearest to this: auditor, salam, columbians, shorthair, saleh, empiricist, premieres, pursue,
# Nearest to or: printer, quatrain, spectrum, accumulator, practice, frequentist, remnants, restraints,
# Nearest to other: pegged, epstein, compaor, zur, beatles, recreational, tyrant, grandmother,
# Average loss at step 2000: 6.575472
# Average loss at step 4000: 5.331438
# Average loss at step 6000: 4.900499
# Average loss at step 8000: 4.586323
# Average loss at step 10000: 4.529515
# Nearest to was: is, were, had, became, are, ikea, davao, cessation,
# Nearest to UNK: o, yule, nance, la, jockeys, toland, planks, assaulted,
# Nearest to they: i, he, them, rocky, centrist, predation, rosh, talkin,
# Nearest to but: does, cafeteria, flush, than, inexpensively, anomalies, towards, until,
# Nearest to united: correctness, conspiring, vfl, conics, procession, mcguire, archdukes, utilities,
# Nearest to years: year, crank, curfew, alene, primacy, tube, transpired, friendship,
# Nearest to which: these, branched, firestorm, refrigerants, that, conformation, categories, macroeconomics,
# Nearest to one: sharpened, dismisses, lilla, chennai, expectation, montreal, brahmagupta, southward,
# Nearest to between: unreleased, moseley, eixample, less, blemish, through, regulus, kutch,
# Nearest to over: across, hinayana, while, throughout, jewishencyclopedia, around, at, within,
# Nearest to has: had, have, having, took, werewolf, squirrel, was, adjoined,
# Nearest to who: engelbert, stele, squandered, sailing, superstardom, haliotis, guard, citations,
# Nearest to after: acheson, before, exhortations, constantius, brasses, mies, basic, tabula,
# Nearest to this: the, whose, a, uriah, overvalued, commandant, johanna, embody,
# Nearest to or: and, mommu, than, ucs, proscription, omaha, taggart, spaced,
# Nearest to other: various, macos, gulch, sportswriters, elin, oceanographer, cour, patten,
# Average loss at step 12000: 4.404309
# Average loss at step 14000: 4.299289
# Average loss at step 16000: 4.340817
# Average loss at step 18000: 4.113374
# Average loss at step 20000: 4.165740
# Nearest to was: is, were, are, became, subgenius, has, being, did,
# Nearest to UNK: paranoia, d, hearts, assaulted, emanates, forma, pani, adverbial,
# Nearest to they: these, insensitivity, hana, ministerio, cac, arrogant, there, i,
# Nearest to but: dolphin, there, hollandic, unfavourably, certifying, ruud, navies, itself,
# Nearest to united: vfl, established, conspiring, procession, typologically, fortress, lemy, redemptive,
# Nearest to years: decades, days, colloquium, months, terror, herders, year, axiomatization,
# Nearest to which: that, silvestris, crispus, antoine, derived, webcomics, but, macroeconomics,
# Nearest to one: app, colitis, cabins, focussed, nashwaak, fela, cessation, fps,
# Nearest to between: eixample, pollination, licensee, gos, objection, macrobiotics, volkov, into,
# Nearest to over: when, brazzaville, gehrig, fencer, abrogated, approximations, within, before,
# Nearest to has: had, have, was, having, is, were, contains, gives,
# Nearest to who: that, transept, ancestries, whom, amati, protege, squirrels, marine,
# Nearest to after: before, during, moldovan, in, of, at, syndromes, intimidate,
# Nearest to this: whose, that, its, the, it, an, josh, toku,
# Nearest to or: misogynist, chancellors, depicting, defining, minefields, conformance, moderated, vociferous,
# Nearest to other: stephenson, burst, thar, pitcairn, rosewood, lakers, ehud, glutamic,
# Average loss at step 22000: 4.119034
# Average loss at step 24000: 4.050126
# Average loss at step 26000: 4.016519
# Average loss at step 28000: 4.007447
# Average loss at step 30000: 3.896971
# Nearest to was: is, were, became, are, remains, makes, came, appears,
# Nearest to UNK: l, jtc, o, bunyan, da, teg, lillard, misadventures,
# Nearest to they: you, decius, we, jelly, addresses, complains, blenheim, their,
# Nearest to but: and, until, although, hickory, since, flu, webber, earthworks,
# Nearest to united: lemy, procession, bomarc, afro, mocha, judson, conspiring, vfl,
# Nearest to years: decades, days, months, year, kilometers, example, hours, period,
# Nearest to which: that, what, while, standardization, bans, who, wilbur, aorist,
# Nearest to one: mysia, isbn, brennan, five, muster, excrement, three, asis,
# Nearest to between: into, with, from, among, eixample, pinned, mulholland, peacekeeping,
# Nearest to over: throughout, during, within, before, senatorial, after, novorossiysk, interpreting,
# Nearest to has: had, have, having, is, was, contains, makes, are,
# Nearest to who: that, which, when, pataki, smiths, whom, what, young,
# Nearest to after: during, before, following, sfg, in, for, until, against,
# Nearest to this: it, a, an, the, brainiac, whose, that, its,
# Nearest to or: comprehensively, and, macduff, sapporo, pio, downloadable, generalisations, venter,
# Nearest to other: various, lindo, certain, all, many, some, cites, patten,
# Average loss at step 32000: 3.777720
# Average loss at step 34000: 3.893404
# Average loss at step 36000: 3.888747
# Average loss at step 38000: 3.967487
# Average loss at step 40000: 3.892195
# Nearest to was: is, became, were, are, being, remains, had, becomes,
# Nearest to UNK: d, notebook, bcpl, bawerk, zolt, sentience, khan, constantius,
# Nearest to they: we, you, these, ancestries, retiring, jehoshaphat, cuisines, legitimate,
# Nearest to but: trevelyan, although, than, necessarily, however, mordred, avenues, hyacinthus,
# Nearest to united: vfl, bukem, officiated, redemptive, conspiring, homophobic, kegan, lemy,
# Nearest to years: decades, days, months, centuries, percent, century, reasons, insignificance,
# Nearest to which: that, this, it, what, whose, carnivore, granary, oems,
# Nearest to one: cyg, six, kilda, four, proletarian, doha, abbotsford, expectation,
# Nearest to between: among, from, licensee, with, click, within, in, across,
# Nearest to over: after, pli, later, throughout, dubnium, around, distort, riddles,
# Nearest to has: had, have, having, is, makes, contains, gave, holds,
# Nearest to who: whom, lusignan, that, penned, phillies, myrdal, lynne, born,
# Nearest to after: during, before, over, through, gardener, following, in, hedwig,
# Nearest to this: the, which, a, what, it, another, brainiac, noticable,
# Nearest to or: repulsion, than, mycology, bomarc, mating, sang, misogynist, rubenstein,
# Nearest to other: various, certain, local, less, different, themselves, rather, dai,
# Average loss at step 42000: 3.870250
# Average loss at step 44000: 3.789553
# Average loss at step 46000: 3.716638
# Average loss at step 48000: 3.716774
# Average loss at step 50000: 3.731918
# Nearest to was: is, were, are, became, makes, becomes, being, remains,
# Nearest to UNK: ecologically, de, inxs, vanes, nobi, coils, elevates, participates,
# Nearest to they: we, you, californians, those, there, others, storehouses, grown,
# Nearest to but: although, dedekind, cbd, nuova, than, ichij, acheson, entirely,
# Nearest to united: nation, meccans, confederate, vfl, forcefully, kegan, lemy, rolled,
# Nearest to years: decades, months, days, year, centuries, reasons, reason, weeks,
# Nearest to which: that, what, who, this, whose, how, where, these,
# Nearest to one: ertegun, anecdotes, kriegsmarine, fistula, suharto, changeable, excrement, millar,
# Nearest to between: eixample, in, licensee, through, within, egyptologist, with, of,
# Nearest to over: oppress, during, across, within, throughout, in, after, detainee,
# Nearest to has: had, have, having, gave, is, contains, was, makes,
# Nearest to who: which, that, whom, what, regicide, some, by, usually,
# Nearest to after: before, until, following, during, penile, afterwards, later, sica,
# Nearest to this: the, it, what, another, which, a, that, its,
# Nearest to or: austral, than, durian, perlman, repulsion, nonsensical, trivium, and,
# Nearest to other: different, rather, various, larger, notches, limitless, gulch, electrolyte,
# Average loss at step 52000: 3.729865
# Average loss at step 54000: 3.552077
# Average loss at step 56000: 3.649426
# Average loss at step 58000: 3.665823
# Average loss at step 60000: 3.595905
# Nearest to was: is, were, remains, becomes, became, are, had, helene,
# Nearest to UNK: evicted, bremen, kun, larps, de, kentucky, illinois, i,
# Nearest to they: you, we, insensitivity, decius, israel, extortion, these, hepatic,
# Nearest to but: although, though, and, nel, imperative, entirely, scorned, necessarily,
# Nearest to united: member, confederate, fire, ira, conspiring, meccans, crusader, other,
# Nearest to years: decades, months, days, year, weeks, centuries, reasons, hours,
# Nearest to which: that, whose, what, this, it, who, where, she,
# Nearest to one: ffg, five, sas, stadia, jokingly, trotskyists, flawed, pyrimidine,
# Nearest to between: eixample, with, licensee, peculiarity, over, vassal, across, schmitz,
# Nearest to over: across, throughout, between, roughly, showered, within, oppress, during,
# Nearest to has: had, have, having, contains, is, produces, gives, exists,
# Nearest to who: he, which, that, beauties, whom, tarantino, whose, when,
# Nearest to after: before, following, for, until, during, despite, since, lifeforms,
# Nearest to this: it, a, which, another, what, an, the, he,
# Nearest to or: than, and, soundboard, denaturation, saddles, geminate, allowing, qualified,
# Nearest to other: various, certain, rather, larger, monazite, midair, lower, these,
# Average loss at step 62000: 3.531475
# Average loss at step 64000: 3.547422
# Average loss at step 66000: 3.692862
# Average loss at step 68000: 3.654751
# Average loss at step 70000: 3.526308
# Nearest to was: is, were, are, became, makes, includes, becomes, remains,
# Nearest to UNK: nearby, ab, gilded, woefully, miriam, inducing, menagerie, ezln,
# Nearest to they: we, you, these, storehouses, ancestries, flavors, naka, who,
# Nearest to but: though, and, when, although, or, subtly, oct, than,
# Nearest to united: member, confederate, commonwealth, ira, incrementally, toll, supporting, lotharingia,
# Nearest to years: months, decades, hours, weeks, year, days, purposes, times,
# Nearest to which: that, what, this, who, it, these, when, whose,
# Nearest to one: gem, safeguard, pohl, diocesan, trotskyists, destroying, mysia, musketeers,
# Nearest to between: eixample, throughout, across, with, within, into, in, during,
# Nearest to over: during, beyond, across, veto, before, riddles, interned, long,
# Nearest to has: had, have, having, is, contains, produces, provides, requires,
# Nearest to who: what, he, which, that, whom, whose, it, traditionally,
# Nearest to after: following, before, during, despite, throughout, when, without, until,
# Nearest to this: it, which, what, the, a, that, whose, another,
# Nearest to or: and, while, toriyama, asean, orientalist, maximization, gonads, but,
# Nearest to other: many, various, both, separate, rather, certain, including, different,
# Average loss at step 72000: 3.480597
# Average loss at step 74000: 3.582579
# Average loss at step 76000: 3.577824
